# %% [markdown]
# # Use the Superstore_USA data and find the following scenarios
#
#
#     - Create a Combo Bar & Line chart
#
#     - Show the Sales & Profit with two different visual in one chart i.e. Sales as Bar graph and Profit as a line chart.
#
#     - Make sure to have different colors for different Charts.
#
# Answer :-- All are answered in the Sheet screenshot below

# %% [markdown]
# ![image.png](attachment:image.png)
