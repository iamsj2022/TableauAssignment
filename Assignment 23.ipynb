# %% [markdown]
# # Use the Superstore_USA data and do the following

# %% [markdown]
# Create visuals in order to showcase the following visual segments
#
#     - Composition
# image.png
#
#     - Comparison :
# image-2.png
#
#     - Relation
# image-3.png
#
#     - Trend
# image-4.png
# image-5.png
#
#     - Geo Maps
# image-6.png

# %% [markdown]
# # Already Covered in Assignment 20

# %% [markdown]
# Develop a Dashbaord and with all the visuals and Save your work.
#
#
# ![image.png](attachment:image.png)
