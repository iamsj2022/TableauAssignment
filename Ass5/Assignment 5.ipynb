# %% [markdown]
# # Project

# %% [markdown]
#  A British company has been growing its business since its infancy stage. Their sales have been good as they deal with Office infrastructure. However, the VP Sales is not very happy with the refunds that the Company has been providing to its Customers. The VP wanted a decision driven method to be employed rather than a traditional approach to derive a strategy.
#
# Solution –
#
#     As a first step the VP planned to evaluate all the BI tools available in the market. Tableau was selected as it met his requirements. Using Tableau, he wanted his team members to give him the forecast of Sales for the next year as well as the probability of refunds category wise for a year. This will help him plan his next steps to avoid the refunds. He wanted a dashboard that would contain the following:

# %% [markdown]
#     A• A list of Order returned by the Customers from Top 10 Countries (in terms of
#     refund)
#     B• Top 10 Countries mapped on the World Map that had most of the refunds
#     C• Predict the refund for next 1 year category-wise

# %% [markdown]
# Actions to be Performed to Create the Dashboard

# %% [markdown]
#     A• Create Hierarchies and Folders in the dataset provided
#     B• Generate a list of order returned from customers and compare it to the
#     original sales, sort the visualization in ascending order in terms of returned
#     order, for top 10 countries in terms of refunds.
#     C• Map top 10 countries, with most of the refunds on the world map
#     D• Predict the returned sale with lowest and actual forecast of the data
#     E• Add a URL action to represent details of the countries
#     F• Finally publish your work to Tableau Server/ Online

# %% [markdown]
# A• A list of Order returned by the Customers from Top 10 Countries (in terms of
# refund)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# B• Top 10 Countries mapped on the World Map that had most of the refunds

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C• Predict the refund for next 1 year category-wise

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A• Create Hierarchies and Folders in the dataset provided
#
# ![image.png](attachment:image.png)

# %% [markdown]
# B• Generate a list of order returned from customers and compare it to the original sales, sort the visualization in ascending order in terms of returned order, for top 10 countries in terms of refunds.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C• Map top 10 countries, with most of the refunds on the world map

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# D• Predict the returned sale with lowest and actual forecast of the data

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# E• Add a URL action to represent details of the countries
#
# ![image.png](attachment:image.png)

# %% [markdown]
# F• Finally publish your work to Tableau Server/ Online
#
# ![image.png](attachment:image.png)
