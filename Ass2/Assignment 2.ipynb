# %% [markdown]
# 1.Use – Superstore_Canada.xls and format your numbers exactly like shown in screenshot below ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Use – Superstore_Canada.xls and format your numbers exactly like shown in screenshot below

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. Import – Superstore_Canada.xls (Sheet – Orders) and answer the following questions:

# %% [markdown]
# A. What is the total sales of the store?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# B. What is the total sales of product category = “Furniture”?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# C. What is the total sales of product category = “Furniture” sold to Customer Segment = “Corporate”?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# D. Set the default number format of Discount to percentage with 2 decimal places.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# E. Find average discount on each order priority. Which order priority has highest average discount?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Import – Superstore_Canada.csv and answer the following questions :

# %% [markdown]
# A. For Product Container = “Large Box” which Ship Mode has lowest
# average shipping cost? (Express Air)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Express Air

# %% [markdown]
# B. For Product Container = “Medium Box” which Ship Mode has lowest
# average shipping cost?

# %% [markdown]
# Regular Air
#
# ![image.png](attachment:image.png)

# %% [markdown]
# C. Which Ship Mode uses only “Jumbo” sized Product Containers? (Delivery
# Truck)

# %% [markdown]
# Delivery Truck
# ![image.png](attachment:image.png)

# %% [markdown]
# D. Which Ship Mode doesn’t entertain “Jumbo” sized Product Containers?

# %% [markdown]
# Regular Air
#
# ![image.png](attachment:image.png)
