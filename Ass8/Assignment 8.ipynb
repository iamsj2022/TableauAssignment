# %% [markdown]
# Use the Superstore_USA data and find the customer loyalty on the following scenarios :--
#
#         1.How much sales has come from customer from the previous in the currentyear in terms of Sales Value.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#  2.How much sales has come from customer from the previous in the currentyear in terms of Sales Percentage.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
#         3.Find the orders placed by each customers
#
#
# ![image.png](attachment:image.png)
