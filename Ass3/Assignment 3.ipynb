# %% [markdown]
# 1.Out of all the products shipped in year 2010 which was the largest selling products (interms of Sales) ?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.Of all the products shipped in June 2009 which had the highest quantity?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. 3.As per the order date what was the total profit generated by Product Category = “Office Supplies “ between 1st Aug 2010 to Aug 2012 ?

# %% [markdown]
# ![image.png](attachment:image.png)
