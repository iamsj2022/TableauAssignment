# %% [markdown]
#     1. Death Rate in colors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # DR & Populations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Prominent Cities with Large populations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Death rate of cities

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #  Create group for Costal Cities,Create a filter on Coastal Cities & Change Map Layers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Use the Global Data and Create Heirarchy with Continent with diff Population With Diff Symbol

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Determine the Inc/Dec in Population

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
